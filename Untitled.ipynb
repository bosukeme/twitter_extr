# %%
import pandas as pd
import twint
import os
from datetime import datetime
import nest_asyncio
from time import sleep
pd.options.mode.chained_assignment = None
nest_asyncio.apply()

# %%
import pandas as pd
import twint
import os
from datetime import datetime
import nest_asyncio
from time import sleep
pd.options.mode.chained_assignment = None
nest_asyncio.apply()


def twint_to_pandas(columns):
    return twint.output.panda.Tweets_df[columns]

def get_latest_tweets_from_handle(username, num_tweets, date):
    c = twint.Config()
    c.Username = username
    c.Limit = num_tweets
    c.Pandas = True
    c.Since = date
    c.Hide_output = True
    twint.run.Search(c)
    try:
        tweet_df = twint_to_pandas(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags', 
               'username', 'name', 'link', 'urls', 'photos', 'video',
               'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'])
    except Exception as e:
        print(e)
        tweet_df = pd.DataFrame()
    sleep(5)
    return tweet_df


def get_latest_tweets_for_publications(rss_publication_df, num_tweets, since_date_str):
    ## Get the latest tweets that have been published by these publications in the last 3 hours
    latest_tweet_df_list = []
    for i in range(len(rss_publication_df)):
        try:
            rss_twitter_handle = rss_publication_df['Publication Handle'].iloc[i]
            print(rss_twitter_handle)
            tweet_df = get_latest_tweets_from_handle(rss_twitter_handle, num_tweets, since_date_str)
            tweet_df['twitter_handle'] = rss_twitter_handle
            print(len(tweet_df))
            print()
            if len(tweet_df) > 0:
                tweet_df = tweet_df.sort_values(by='nreplies', ascending=False)
                latest_tweet_df_list.append(tweet_df)
        except Exception as e:
            print(e)
            ...
    ## Now run through all the tweets and filter out those that dont have article links
    latest_tweets_df = pd.concat(latest_tweet_df_list, sort=True)
    tweet_w_link_indices = []
    link_tweet_w_comment_indices = []
    for ii in range(len(latest_tweets_df)):
        tweet_text = latest_tweets_df.iloc[ii]['tweet']
        tweet_urls = latest_tweets_df.iloc[ii]['urls']
        num_tweet_comments = latest_tweets_df.iloc[ii]['nreplies']
        if len(tweet_urls) > 0:
            tweet_w_link_indices.append(ii)
    article_tweets_df = latest_tweets_df.iloc[tweet_w_link_indices]
    
    return article_tweets_df

def last_n_hours(num):
    time_diff = num
    today = datetime.now() 
    date = today.date()
    since_hour = max(0, today.hour - time_diff)
    minute = today.minute
    second = '00'
    since_date_str = '%s %s:%s:%s' % (date, since_hour, minute, second)

    return since_date_str


def get_artilces_30_to_45_min_old(rss_publication_df, num_tweets, last_hour_date_str):
    all_articles = get_latest_tweets_for_publications(rss_publication_df, num_tweets, last_hour_date_str)
    
    all_articles["run_time"] = datetime.now()
    all_articles["run_time"] = all_articles.apply(lambda row: (datetime.strftime(row["run_time"], '%Y-%m-%d %H:%M:%S')),axis=1)
    
    all_articles['date'] = pd.to_datetime(all_articles['date'], format = '%Y-%m-%d %H:%M:%S')
    
    all_articles['time_since_tweet'] = all_articles.apply(lambda row: (datetime.strptime(row.run_time, '%Y-%m-%d %H:%M:%S') - row.date).total_seconds()/60, axis=1)
    
    all_articles = all_articles[(all_articles['time_since_tweet'] <= 45) & (all_articles['time_since_tweet'] >= 30)]

    
    return all_articles

rss_twitter_handles_path = os.path.join(os.getcwd(), 'launch_rss_publications.csv')
rss_publication_df = pd.read_csv(rss_twitter_handles_path)
num_tweets = 1000
last_hour_date_str = last_n_hours(1)

processed_tweet = get_artilces_30_to_45_min_old(rss_publication_df, num_tweets, last_hour_date_str)
processed_tweet['total'] = processed_tweet.apply(lambda row: row['nlikes'] + row['nreplies'] + row['nretweets'], axis=1)
new_df_2 = pd.merge(pro_tweet_2, dff, on='username')

new_df_2['cut_off'] = new_df_2.apply(lambda row:  row['average_nreactions'] - row['average_nreactions']/5,axis=1)

new_filtered = new_df_2[new_df_2.apply(lambda row:  row['total']>= row['cut_off'] , axis=1)]



def save_to_unfiltered_collection(df):
    unfiltered_collection = db.unfiltered_collection
    cur = unfiltered_collection.count_documents({})
    print('We had %s  entries at the start' % cur)
    
    
    id_list=list(unfiltered_collection.find({}, {"_id": 0, "id": 1}))
    id_list=list((val for dic in id_list for val in dic.values()))
    
    for dfs in df.to_dict('records'):
        if dfs['id'] not in id_list:
            unfiltered_collection.insert_one(dfs)

save_to_unfiltered_collection(new_df_2)

def save_to_filtered_collection(df):
    filtered_collection = db.filtered_collection
    cur = filtered_collection.count_documents({})
    print('We had %s  entries at the start' % cur)
    
    
    id_list=list(filtered_collection.find({}, {"_id": 0, "id": 1}))
    id_list=list((val for dic in id_list for val in dic.values()))
    
    for dfs in df.to_dict('records'):
        if dfs['id'] not in id_list:
            filtered_collection.insert_one(dfs)

save_to_filtered_collection(new_filtered)

# %%
def last_n_hours(num):
    time_diff = num
    today = datetime.now() 
    date = today.date()
    since_hour = max(0, today.hour - time_diff)
    minute = today.minute
    second = '00'
    since_date_str = '%s %s:%s:%s' % (date, since_hour, minute, second)

    return since_date_str

# %%
def get_artilces_30_to_45_min_old(rss_publication_df, num_tweets, last_hour_date_str):
    all_articles = get_latest_tweets_for_publications(rss_publication_df, num_tweets, last_hour_date_str)
    
    all_articles["run_time"] = datetime.now()
    all_articles["run_time"] = all_articles.apply(lambda row: (datetime.strftime(row["run_time"], '%Y-%m-%d %H:%M:%S')),axis=1)
    
    all_articles['date'] = pd.to_datetime(all_articles['date'], format = '%Y-%m-%d %H:%M:%S')
    
    all_articles['time_since_tweet'] = all_articles.apply(lambda row: (datetime.strptime(row.run_time, '%Y-%m-%d %H:%M:%S') - row.date).total_seconds()/60, axis=1)
    
    all_articles = all_articles[(all_articles['time_since_tweet'] <= 45) & (all_articles['time_since_tweet'] >= 30)]

    
    return all_articles

# %%
rss_twitter_handles_path = os.path.join(os.getcwd(), 'launch_rss_publications.csv')
rss_publication_df = pd.read_csv(rss_twitter_handles_path)
num_tweets = 1000
last_hour_date_str = last_n_hours(1)

# %%
processed_tweet = get_artilces_30_to_45_min_old(rss_publication_df, num_tweets, last_hour_date_str)
# Out:
# gazettengr
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# politico
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 4
#
# breitbartnews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# VentureBeat
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 4
#
# startup_wonders
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# ctvnews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 8
#
# ForbesTech
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# ScienceNews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# indstartupnews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# indianexpress
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# crunchbasenews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# FastCoImpact
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# vanguardngrnews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 9
#
# ft
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# seattle20
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# movieweb
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 2
#
# TechCrunch
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 8
#
# SiliconBayou
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# bbctech
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# usweekly
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 2
#
# MetroUK
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# Inc42
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# WIRED
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# thetechstartups
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# standardkenya
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 2
#
# mashable
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 8
#
# bogotapost
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# mental_floss
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 2
#
# verge
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 5
#
# Nairametrics
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 13
#
# StartupNewsFyi
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# StartupDailyANZ
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# dailymailuk
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 7
#
# HarvardBiz
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# hollywoodlife
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 2
#
# cnn
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 6
#
# engadget
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 5
#
# DisruptAfrica
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# ETIndustryNews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# torontostar
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 9
#
# BusinessInsider
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 6
#
# comingsoonnet
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 4
#
# cbsnews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 5
#
# TechTrendsKE
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# RWW
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# marketwatch
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 6
#
# Entrepreneur
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# techfruit
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# NoCamels
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# TechRoundUK
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# techdotlondon
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# syemprende
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# WSJVC
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# Recode
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# bbcworld
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 5
#
# nypost
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 12
#
# WRALTechWire
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# LaffazMedia
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# OresundStartups
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# AustinStartups
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# tmz
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 9
#
# CNET
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 5
#
# 150sec
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# techinasia
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# citynews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# bbcnews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 9
#
# people
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 12
#
# nbcnews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 5
#
# geektimees
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# guardian
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 9
#
# bbchealth
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# startupbeat1
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# EU_Startups
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# TOIStartup
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# Independent
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 22
#
# skycricket
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 4
#
# ETtech
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# Siftedeu
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# TechInsider
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# thecableng
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 5
#
# saharareporters
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# nationalpost
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 5
#
# StartupNewsAus
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# YourStoryCo
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# foxnews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 8
#
# thenextweb
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 6
#
# Inc
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 5
#
# 9to5mac
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 7
#
# FastCompany
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 4
#
# THISDAYLIVE
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# thesociable
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# globalnews
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 3
#
# Gizmodo
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 2
#
# skysportspl
# CRITICAL:root:twint.get:User:[WinError 10054] An existing connection was forcibly closed by the remote host
# [WinError 10054] An existing connection was forcibly closed by the remote host
# fourfourtwo
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 1
#
# pulseghana
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# 7
#
# Graphicgh
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0
#
# GhanaWeb
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# "None of [Index(['id', 'conversation_id', 'date', 'tweet', 'language', 'hashtags',\n       'username', 'name', 'link', 'urls', 'photos', 'video', 'thumbnail',\n       'retweet', 'nlikes', 'nreplies', 'nretweets', 'source'],\n      dtype='object')] are in the [columns]"
# 0

# %%
processed_tweet
# Out:
#         conversation_id                date hashtags                   id  \
# 0   1400095572082761730 2021-06-02 15:22:51       []  1400095572082761730
# 1   1400097495976456192 2021-06-02 15:30:30       []  1400097495976456192
# 0   1400097934327402500 2021-06-02 15:32:14       []  1400097934327402500
# 1   1400094476438106112 2021-06-02 15:18:30       []  1400094476438106112
# 3   1400096078465208325 2021-06-02 15:24:52       []  1400096078465208325
# ..                  ...                 ...      ...                  ...
# 0   1400097752844021766 2021-06-02 15:31:31       []  1400097752844021766
# 1   1400097078471241732 2021-06-02 15:28:50       []  1400097078471241732
# 2   1400095251759517703 2021-06-02 15:21:35       []  1400095251759517703
# 1   1400097129322844171 2021-06-02 15:29:02       []  1400097129322844171
# 3   1400094854311337987 2021-06-02 15:20:00       []  1400094854311337987
#
#    language                                               link  \
# 0        en  https://twitter.com/GazetteNGR/status/14000955...
# 1        en  https://twitter.com/politico/status/1400097495...
# 0        en  https://twitter.com/BreitbartNews/status/14000...
# 1        en  https://twitter.com/VentureBeat/status/1400094...
# 3        en  https://twitter.com/CTVNews/status/14000960784...
# ..      ...                                                ...
# 0        en  https://twitter.com/THISDAYLIVE/status/1400097...
# 1        en  https://twitter.com/THISDAYLIVE/status/1400097...
# 2        en  https://twitter.com/globalnews/status/14000952...
# 1        en  https://twitter.com/Gizmodo/status/14000971293...
# 3        en  https://twitter.com/PulseGhana/status/14000948...
#
#                name  nlikes  nreplies  nretweets  ... retweet  source  \
# 0   Peoples Gazette      36         5         19  ...   False
# 1          POLITICO      18        11          8  ...   False
# 0    Breitbart News      38        16         10  ...   False
# 1       VentureBeat       8         0          4  ...   False
# 3          CTV News      11         7          7  ...   False
# ..              ...     ...       ...        ...  ...     ...     ...
# 0      THISDAY LIVE       7         4          0  ...   False
# 1      THISDAY LIVE      10         2          2  ...   False
# 2     Globalnews.ca      18         2          1  ...   False
# 1           Gizmodo       6         1          1  ...   False
# 3       Pulse Ghana      32         2          2  ...   False
#
#                                           thumbnail  \
# 0
# 1   https://pbs.twimg.com/media/E24lQNfXMAEimTJ.jpg
# 0
# 1
# 3
# ..                                              ...
# 0
# 1
# 2
# 1
# 3   https://pbs.twimg.com/media/E24gtJLXwAIxqQ6.jpg
#
#                                                 tweet twitter_handle  \
# 0   Bill to end HND-Bachelors degree dichotomy pas...     gazettengr
# 1   The military’s “wish lists” outline needs for ...       politico
# 0                Good grief.  https://t.co/R355kibJeZ  breitbartnews
# 1   Salesforce boosts customer data platform strat...    VentureBeat
# 3   Deaths from COVID-19 reduced Canadian life exp...        ctvnews
# ..                                                ...            ...
# 0   USAID Donates $10m in Support of FG's Initiati...    THISDAYLIVE
# 1   Senate Okays Bill to End Discrimination betwee...    THISDAYLIVE
# 2   Wednesday marks the third straight day Ontario...     globalnews
# 1   Please Give All the Awards to This Mind-Meltin...        Gizmodo
# 3   Man jailed 9 months for beating stranger who s...     pulseghana
#
#                                                  urls       username video  \
# 0   [https://gazettengr.com/bill-to-end-hnd-bachel...     GazetteNGR     0
# 1                         [https://politi.co/3vWYWRv]       politico     1
# 0                           [https://trib.al/5gnGVjN]  BreitbartNews     0
# 1                         [https://wp.me/p8wLEc-biPX]    VentureBeat     0
# 3   [https://www.ctvnews.ca/health/coronavirus/pan...        CTVNews     0
# ..                                                ...            ...   ...
# 0   [https://www.thisdaylive.com/index.php/2021/06...    THISDAYLIVE     0
# 1   [https://www.thisdaylive.com/index.php/2021/06...    THISDAYLIVE     0
# 2                           [https://trib.al/hj7CzMC]     globalnews     0
# 1                             [http://dlvr.it/S0wV1x]        Gizmodo     0
# 3                            [https://bit.ly/34BRLlA]     PulseGhana     1
#
#                run_time time_since_tweet
# 0   2021-06-02 16:02:48        39.950000
# 1   2021-06-02 16:02:48        32.300000
# 0   2021-06-02 16:02:48        30.566667
# 1   2021-06-02 16:02:48        44.300000
# 3   2021-06-02 16:02:48        37.933333
# ..                  ...              ...
# 0   2021-06-02 16:02:48        31.283333
# 1   2021-06-02 16:02:48        33.966667
# 2   2021-06-02 16:02:48        41.216667
# 1   2021-06-02 16:02:48        33.766667
# 3   2021-06-02 16:02:48        42.800000
#
# [73 rows x 21 columns]

# %%
#processed_tweet['total'] = 0
processed_tweet['total'] = processed_tweet.apply(lambda row: row['nlikes'] + row['nreplies'] + row['nretweets'], axis=1)

# %%
# 43  2021-06-02 16:02:48        36.266667     39          94.600000
# 44  2021-06-02 16:02:48        33.950000     15          94.600000
# 45  2021-06-02 16:02:48        41.916667     17          94.600000
# 46  2021-06-02 16:02:48        31.833333      6          94.600000
# 47  2021-06-02 16:02:48        39.266667     24          99.000000
# 48  2021-06-02 16:02:48        31.816667     10          99.000000
# 49  2021-06-02 16:02:48        32.200000    454         257.937500
# 50  2021-06-02 16:02:48        42.200000    230         257.937500
# 51  2021-06-02 16:02:48        37.750000     27          86.363636
# 52  2021-06-02 16:02:48        43.616667     88         107.500000
# 53  2021-06-02 16:02:48        40.766667     75         107.500000
# 54  2021-06-02 16:02:48        41.216667     21          68.000000
# 55  2021-06-02 16:02:48        33.766667      8          82.666667
# 56  2021-06-02 16:02:48        42.800000     36         109.538462
#
# [57 rows x 23 columns]

# %%
new_df_2.to_csv("tweet_extract_30_45mins.csv", index=False)

# %%
new_df_2['cut_off'] = new_df_2.apply(lambda row:  row['average_nreactions'] - row['average_nreactions']/5,axis=1)

# %%
new_filtered = new_df_2[new_df_2.apply(lambda row:  row['total']>= row['cut_off'] , axis=1)]

# %%
tweet_extract_30_45mins.csv

# %%
new_filtered.to_csv("tweet_extract_30_45mins_filtered.csv", index=False)

# %%
from collections import Counter
Counter(new_df_2['username'].to_list())
# Out:
# Counter({'GazetteNGR': 1,
#          'politico': 1,
#          'BreitbartNews': 1,
#          'CTVNews': 4,
#          'IndianExpress': 1,
#          'vanguardngrnews': 7,
#          'WIRED': 1,
#          'mashable': 2,
#          'verge': 1,
#          'DailyMailUK': 2,
#          'HarvardBiz': 1,
#          'CNN': 1,
#          'engadget': 1,
#          'TorontoStar': 1,
#          'BusinessInsider': 1,
#          'CBSNews': 2,
#          'MarketWatch': 2,
#          'BBCWorld': 1,
#          'nypost': 3,
#          'TMZ': 1,
#          'CNET': 1,
#          'BBCNews': 2,
#          'people': 4,
#          'guardian': 1,
#          'Independent': 4,
#          'nationalpost': 2,
#          'FoxNews': 2,
#          'Inc': 1,
#          '9to5mac': 2,
#          'globalnews': 1,
#          'Gizmodo': 1,
#          'PulseGhana': 1})

# %%
Counter(new_filtered['username'].to_list())
# Out:
# Counter({'verge': 1,
#          'CNN': 1,
#          'CBSNews': 1,
#          'BBCWorld': 1,
#          'nypost': 1,
#          'BBCNews': 1,
#          'FoxNews': 2,
#          '9to5mac': 1})

# %%
pro_tweet_1 = processed_tweet

# %%
new_df_1 = pd.merge(pro_tweet_1, dff, on='username')
new_df_1[new_df_1['twitter_handle']=="breitbartnews"]
# Out:
# Empty DataFrame
# Columns: [conversation_id, date, hashtags, id, language, link, name, nlikes, nreplies, nretweets, photos, retweet, source, thumbnail, tweet, twitter_handle, urls, username, video, run_time, time_since_tweet, total, average_nreactions]
# Index: []
#
# [0 rows x 23 columns]

# %%
pro_tweet = processed_tweet

# %%
dff = pd.read_csv("average_reaction_monday.csv")
dff
# Out:
#            username  average_nreactions
# 0           9to5mac          107.500000
# 1           BBCNews          169.075472
# 2          BBCWorld          344.683333
# 3     BreitbartNews          498.833333
# 4   BusinessInsider          107.500000
# 5           CBSNews          152.000000
# 6              CNET           82.500000
# 7               CNN          434.081081
# 8           CTVNews          100.875000
# 9          CityNews           86.000000
# 10      DailyMailUK          104.375000
# 11               FT           86.666667
# 12      FourFourTwo          141.000000
# 13          FoxNews          257.937500
# 14       GazetteNGR          116.642857
# 15          Gizmodo           82.666667
# 16       HarvardBiz          129.673913
# 17              Inc           86.363636
# 18      Independent           94.600000
# 19    IndianExpress          102.888889
# 20      MarketWatch           80.666667
# 21          NBCNews          161.209302
# 22       PulseGhana          109.538462
# 23  SaharaReporters          240.681818
# 24      ScienceNews           85.875000
# 25       SkyCricket          124.000000
# 26      SkySportsPL          621.000000
# 27    StandardKenya           68.000000
# 28              TMZ          122.567568
# 29       TechCrunch           69.000000
# 30      TorontoStar           94.000000
# 31            WIRED          216.846154
# 32         engadget           86.000000
# 33       globalnews           68.000000
# 34         guardian          148.085271
# 35         mashable           83.000000
# 36     nationalpost           99.000000
# 37           nypost          173.268571
# 38           people          126.411765
# 39         politico          149.500000
# 40       thecableng          126.333333
# 41  vanguardngrnews          113.260870
# 42            verge          139.956522

# %%
new_df = pd.merge(pro_tweet, dff, on='username')

# %%
new_df[new_df['Twitter Handle']=="breitbartnews"]
# Out:
# Empty DataFrame
# Columns: [Twitter Handle, conversation_id, date, hashtags, id, language, link, name, nlikes, nreplies, nretweets, photos, retweet, source, thumbnail, tweet, urls, username, video, run_time, time_since_tweet, total, average_nreactions]
# Index: []
#
# [0 rows x 23 columns]

# %%
def save_unfiltered(df, unfiltered_json):
# dir_to_json_file = "ukeme.json"
# df_to_append = new_df_2

    if os.path.isfile(dir_to_json_file):
        # if exist open read it
        df_read = pd.read_json(dir_to_json_file, orient='index')
        # add data that you want to save
        df_read = pd.concat([df_read, df_to_append], ignore_index=True)
        # in case of adding to much unnecessery data (if you need)
        #df_read.drop_duplicates(inplace=True)

        # save it to json file in AppData.bin
        df_read.to_json(dir_to_json_file, orient='index')
    else:
        df_to_append.to_json(dir_to_json_file, orient='index')

save_unfiltered(new_df_2, "unfiltered.json")

# %%
def save_filtered(df, unfiltered_json):
# dir_to_json_file = "ukeme.json"
# df_to_append = new_df_2

    if os.path.isfile(dir_to_json_file):
        # if exist open read it
        df_read = pd.read_json(dir_to_json_file, orient='index')
        # add data that you want to save
        df_read = pd.concat([df_read, df_to_append], ignore_index=True)
        # in case of adding to much unnecessery data (if you need)
        #df_read.drop_duplicates(inplace=True)

        # save it to json file in AppData.bin
        df_read.to_json(dir_to_json_file, orient='index')
    else:
        df_to_append.to_json(dir_to_json_file, orient='index')

save_unfiltered(new_df_2, "unfiltered.json")

# %%
new_df_1
# Out:
#         conversation_id                date hashtags                   id  \
# 0   1400084696965517322 2021-06-02 14:39:38       []  1400084696965517322
# 1   1400085893172563976 2021-06-02 14:44:23       []  1400085893172563976
# 2   1400083727510876160 2021-06-02 14:35:47       []  1400083727510876160
# 3   1400082304584781826 2021-06-02 14:30:08       []  1400082304584781826
# 4   1400083711333474312 2021-06-02 14:35:43       []  1400083711333474312
# 45  https://twitter.com/Independent/status/1400095...
# 46  https://twitter.com/Independent/status/1400097...
# 47  https://twitter.com/nationalpost/status/140009...
# 48  https://twitter.com/nationalpost/status/140009...
# 49  https://twitter.com/FoxNews/status/14000975223...
# 50  https://twitter.com/FoxNews/status/14000950069...
# 51  https://twitter.com/Inc/status/140009612443479...
# 52  https://twitter.com/9to5mac/status/14000946496...
# 53  https://twitter.com/9to5mac/status/14000953648...
# 54  https://twitter.com/globalnews/status/14000952...
# 55  https://twitter.com/Gizmodo/status/14000971293...
# 56  https://twitter.com/PulseGhana/status/14000948...
#
#                        name  nlikes  nreplies  nretweets  ...  \
# 0           Peoples Gazette      36         5         19  ...
# 1                  POLITICO      18        11          8  ...
# 2            Breitbart News      38        16         10  ...
# 3                  CTV News      11         7          7  ...
# 4                  CTV News      34         1          8  ...
# 5                  CTV News       1         0          1  ...
# 6                  CTV News      27         0          3  ...
# 7        The Indian Express      19         0          2  ...
# 8       Vanguard Newspapers      42        21         22  ...
# 9       Vanguard Newspapers      29         7         11  ...
# 10      Vanguard Newspapers      18         6          2  ...
# 11      Vanguard Newspapers      15         4          7  ...
# 12      Vanguard Newspapers      21         1          3  ...
# 13      Vanguard Newspapers       5         1          0  ...
# 14      Vanguard Newspapers      11         0          3  ...
# 15                    WIRED      46         0         17  ...
# 16                 Mashable       5         0          3  ...
# 17                 Mashable      13         0          6  ...
# 18                The Verge     215        16         26  ...
# 19          Daily Mail U.K.       9         6          2  ...
# 20          Daily Mail U.K.       6         1          2  ...
# 21  Harvard Business Review      46         1          5  ...
# 22                      CNN     266        59         65  ...
# 23                 Engadget      24         0          3  ...
# 24             Toronto Star      18         9          8  ...
# 25         Business Insider      43         1         14  ...
# 26                 CBS News      47        57         31  ...
# 27                 CBS News      34         7         15  ...
# 28              MarketWatch      25         9         14  ...
# 29              MarketWatch       4         3          3  ...
# 30         BBC News (World)     198        20         62  ...
# 31            New York Post     151        54         42  ...
# 32            New York Post       9         5          3  ...
# 33            New York Post      44         3         12  ...
# 34                      TMZ      30         8          5  ...
# 35                     CNET      18         1          8  ...
# 36            BBC News (UK)     115        16         27  ...
# 37            BBC News (UK)      75        11         16  ...
# 38                   People      78         1         11  ...
# 39                   People      36         1          8  ...
# 40                   People       5         0          4  ...
# 41                   People      21         0          9  ...
# 42             The Guardian      47         4         15  ...
# 43          The Independent      23         6         10  ...
# 44          The Independent       8         3          4  ...
# 45          The Independent      10         1          6  ...
# 46          The Independent       5         0          1  ...
# 47            National Post      15         7          2  ...
# 48            National Post       8         1          1  ...
# 49                 Fox News     306       102         46  ...
# 50                 Fox News     174        30         26  ...
# 51                     Inc.      19         1          7  ...
# 52              9to5Mac.com      70         4         14  ...
# 53              9to5Mac.com      63         0         12  ...
# 54            Globalnews.ca      18         2          1  ...
# 55                  Gizmodo       6         1          1  ...
# 56              Pulse Ghana      32         2          2  ...
#
#                                                 tweet   twitter_handle  \
# 0   Bill to end HND-Bachelors degree dichotomy pas...       gazettengr
# 1   The military’s “wish lists” outline needs for ...         politico
# video                                                               0
# run_time                                                1622646868000
# time_since_tweet                                            30.083333
# total                                                               9
# average_nreactions                                         116.642857
# cut_off                                                          None
#
#                                                                   2    \
# conversation_id                                   1400083727510876160
# date                                                    1622644547000
# hashtags                                                           []
# id                                                1400083727510876160
# language                                                           en
# link                https://twitter.com/CTVNews/status/14000837275...
# name                                                         CTV News
# nlikes                                                             47
# nreplies                                                           44
# nretweets                                                           4
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               Kenney speaks out against 'cancel culture' in ...
# twitter_handle                                                ctvnews
# urls                [https://calgary.ctvnews.ca/kenney-speaks-out-...
# username                                                      CTVNews
# video                                                               0
# run_time                                                1622646868000
# time_since_tweet                                            38.683333
# total                                                              95
# average_nreactions                                            100.875
# cut_off                                                          None
#
#                                                                   3    \
# conversation_id                                   1400082304584781824
# date                                                    1622644208000
# hashtags                                                           []
# id                                                1400082304584781824
# language                                                           en
# link                https://twitter.com/CTVNews/status/14000823045...
# name                                                         CTV News
# nlikes                                                             17
# nreplies                                                           12
# nretweets                                                           2
# photos              [https://pbs.twimg.com/media/E24Xb8xWEAs-_MP.jpg]
# retweet                                                         False
# source
# thumbnail             https://pbs.twimg.com/media/E24Xb8xWEAs-_MP.jpg
# tweet               Iran's largest navy ship catches fire, sinks i...
# twitter_handle                                                ctvnews
# urls                [https://www.ctvnews.ca/world/iran-s-largest-n...
# username                                                      CTVNews
# video                                                               1
# run_time                                                1622646868000
# time_since_tweet                                            44.333333
# total                                                              31
# average_nreactions                                            100.875
# cut_off                                                          None
#
#                                                                   4    \
# conversation_id                                   1400083711333474304
# date                                                    1622644543000
# hashtags                                                           []
# id                                                1400083711333474304
# language                                                           en
# link                https://twitter.com/vanguardngrnews/status/140...
# name                                              Vanguard Newspapers
# nlikes                                                             67
# nreplies                                                           20
# nretweets                                                          19
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               Twitter deletes Buhari's civil war tweet amid ...
# twitter_handle                                        vanguardngrnews
# urls                [https://community.vanguardngr.com/forum/topic...
# username                                              vanguardngrnews
# video                                                               0
# run_time                                                1622646868000
# time_since_tweet                                                38.75
# total                                                             106
# average_nreactions                                          113.26087
# cut_off                                                          None
#
#                                                                   5    \
# conversation_id                                   1400085459414433792
# date                                                    1622644960000
# hashtags                                                           []
# id                                                1400085459414433792
# language                                                           en
# link                https://twitter.com/FT/status/1400085459414433796
# name                                                  Financial Times
# nlikes                                                             15
# nreplies                                                            2
# nretweets                                                           6
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               US money market funds struggle as short-term r...
# twitter_handle                                                     ft
# urls                                      [https://on.ft.com/3uO8axH]
# username                                                           FT
# video                                                               0
# run_time                                                1622646868000
# time_since_tweet                                                 31.8
# total                                                              23
# average_nreactions                                          86.666667
# cut_off                                                          None
#
#                                                                   6    \
# conversation_id                                   1400083820901191680
# date                                                    1622644569000
# hashtags                                                           []
# id                                                1400083820901191680
# language                                                           en
# link                https://twitter.com/FT/status/1400083820901191685
# name                                                  Financial Times
# nlikes                                                             15
# nreplies                                                            2
# nretweets                                                           3
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               Lex Letter from Seoul: Baby Shark surfs the Mu...
# twitter_handle                                                     ft
# urls                                      [https://on.ft.com/3uJYhBo]
# username                                                           FT
# video                                                               0
# run_time                                                1622646868000
# time_since_tweet                                            38.316667
# total                                                              20
# average_nreactions                                          86.666667
# cut_off                                                          None
#
#                                                                   7    \
# conversation_id                                   1400083252652785664
# date                                                    1622644434000
# hashtags                                                           []
# id                                                1400083252652785664
# language                                                           en
# link                https://twitter.com/TechCrunch/status/14000832...
# name                                                       TechCrunch
# nlikes                                                             79
# nreplies                                                            4
# nretweets                                                          19
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               Amazon to stop screening employees for marijua...
# twitter_handle                                             TechCrunch
# urls                                        [https://tcrn.ch/3uJNdUX]
# username                                                   TechCrunch
# video                                                               0
# run_time                                                1622646868000
# time_since_tweet                                            40.566667
# total                                                             102
# average_nreactions                                               69.0
# cut_off                                                          None
#
#                                                                   8    \
# conversation_id                                   1400083413751762944
# date                                                    1622644472000
# hashtags                                                           []
# id                                                1400083413751762944
# language                                                           en
# link                https://twitter.com/TechCrunch/status/14000834...
# name                                                       TechCrunch
# nlikes                                                             15
# nreplies                                                            0
# nretweets                                                           6
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               FlixMobility raises $650M+ at a $3B valuation ...
# twitter_handle                                             TechCrunch
# urls                                        [https://tcrn.ch/34EyboD]
# username                                                   TechCrunch
# video                                                               0
# run_time                                                1622646868000
# time_since_tweet                                            39.933333
# total                                                              21
# average_nreactions                                               69.0
# cut_off                                                          None
#
#                                                                   9    ...  \
# conversation_id                                   1400084152679022592  ...
# date                                                    1622644648000  ...
# hashtags                                                           []  ...
# id                                                1400084152679022592  ...
# language                                                           en  ...
# link                https://twitter.com/StandardKenya/status/14000...  ...
# name                                             The Standard Digital  ...
# nlikes                                                              4  ...
# nreplies                                                            0  ...
# nretweets                                                           1  ...
# photos                                                             []  ...
# retweet                                                         False  ...
# source                                                                 ...
# thumbnail                                                              ...
# tweet               KenGen starts drilling works on Ethiopia’s Sh7...  ...
# twitter_handle                                          standardkenya  ...
# urls                                       [http://ow.ly/L45q50F16s4]  ...
# username                                                StandardKenya  ...
# video                                                               0  ...
# run_time                                                1622646868000  ...
# time_since_tweet                                                 37.0  ...
# total                                                               5  ...
# average_nreactions                                               68.0  ...
# cut_off                                                          None  ...
#
#                                                                   110  \
# conversation_id                                   1400095741733912578
# date                                                    1622647412000
# hashtags                                                           []
# id                                                1400095741733912578
# language                                                           en
# link                https://twitter.com/nationalpost/status/140009...
# name                                                    National Post
# nlikes                                                             15
# nreplies                                                            7
# nretweets                                                           2
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               U.S. to send Israel $1 billion to replenish Ir...
# twitter_handle                                           nationalpost
# urls                [https://nationalpost.com/news/u-s-senator-exp...
# username                                                 nationalpost
# video                                                               0
# run_time                                          2021-06-02 16:02:48
# time_since_tweet                                            39.266667
# total                                                              24
# average_nreactions                                               99.0
# cut_off                                                          79.2
#
#                                                                   111  \
# conversation_id                                   1400097618181738503
# date                                                    1622647859000
# hashtags                                                   [autonews]
# id                                                1400097618181738503
# language                                                           en
# link                https://twitter.com/nationalpost/status/140009...
# name                                                    National Post
# nlikes                                                              8
# nreplies                                                            1
# nretweets                                                           1
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               Burnaby RCMP charge twins with impaired drivin...
# twitter_handle                                           nationalpost
# urls                [https://driving.ca/auto-news/crashes/identica...
# username                                                 nationalpost
# video                                                               0
# run_time                                          2021-06-02 16:02:48
# time_since_tweet                                            31.816667
# total                                                              10
# average_nreactions                                               99.0
# cut_off                                                          79.2
#
#                                                                   112  \
# conversation_id                                   1400097522375348224
# date                                                    1622647836000
# hashtags                                                           []
# id                                                1400097522375348224
# language                                                           en
# link                https://twitter.com/FoxNews/status/14000975223...
# name                                                         Fox News
# nlikes                                                            306
# nreplies                                                          102
# nretweets                                                          46
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               Virginia parents organize to fight critical ra...
# twitter_handle                                                foxnews
# urls                [https://www.foxnews.com/us/virginia-parents-o...
# username                                                      FoxNews
# video                                                               0
# run_time                                          2021-06-02 16:02:48
# time_since_tweet                                                 32.2
# total                                                             454
# average_nreactions                                           257.9375
# cut_off                                                        206.35
#
#                                                                   113  \
# conversation_id                                   1400095006954774530
# date                                                    1622647236000
# hashtags                                                           []
# id                                                1400095006954774530
# language                                                           en
# link                https://twitter.com/FoxNews/status/14000950069...
# name                                                         Fox News
# nlikes                                                            174
# nreplies                                                           30
# nretweets                                                          26
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               Queen Elizabeth to celebrate Platinum Jubilee ...
# twitter_handle                                                foxnews
# urls                [https://www.foxnews.com/entertainment/queen-e...
# username                                                      FoxNews
# video                                                               0
# run_time                                          2021-06-02 16:02:48
# time_since_tweet                                                 42.2
# total                                                             230
# average_nreactions                                           257.9375
# cut_off                                                        206.35
#
#                                                                   114  \
# conversation_id                                   1400096124434796549
# date                                                    1622647503000
# hashtags                                                           []
# id                                                1400096124434796549
# language                                                           en
# link                https://twitter.com/Inc/status/140009612443479...
# name                                                             Inc.
# nlikes                                                             19
# nreplies                                                            1
# nretweets                                                           7
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               Enhancing your customers' emotions is crucial....
# twitter_handle                                                    Inc
# urls                                      [http://on.inc.com/jJD5K3I]
# username                                                          Inc
# video                                                               0
# run_time                                          2021-06-02 16:02:48
# time_since_tweet                                                37.75
# total                                                              27
# average_nreactions                                          86.363636
# cut_off                                                     69.090909
#
#                                                                   115  \
# conversation_id                                   1400094649612599302
# date                                                    1622647151000
# hashtags                                                           []
# id                                                1400094649612599302
# language                                                           en
# link                https://twitter.com/9to5mac/status/14000946496...
# name                                                      9to5Mac.com
# nlikes                                                             70
# nreplies                                                            4
# nretweets                                                          14
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               It's not just you, Apple confirms Apple Card o...
# twitter_handle                                                9to5mac
# urls                [https://9to5mac.com/2021/06/02/apple-confirms...
# username                                                      9to5mac
# video                                                               0
# run_time                                          2021-06-02 16:02:48
# time_since_tweet                                            43.616667
# total                                                              88
# average_nreactions                                              107.5
# cut_off                                                          86.0
#
#                                                                   116  \
# conversation_id                                   1400095364871491589
# date                                                    1622647322000
# hashtags                                                           []
# id                                                1400095364871491589
# language                                                           en
# link                https://twitter.com/9to5mac/status/14000953648...
# name                                                      9to5Mac.com
# nlikes                                                             63
# nreplies                                                            0
# nretweets                                                          12
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               Gallery: Swift Student Challenge winners begin...
# twitter_handle                                                9to5mac
# urls                [https://9to5mac.com/2021/06/02/wwdc-2021-swag...
# username                                                      9to5mac
# video                                                               0
# run_time                                          2021-06-02 16:02:48
# time_since_tweet                                            40.766667
# total                                                              75
# average_nreactions                                              107.5
# cut_off                                                          86.0
#
#                                                                   117  \
# conversation_id                                   1400095251759517703
# date                                                    1622647295000
# hashtags                                                           []
# id                                                1400095251759517703
# language                                                           en
# link                https://twitter.com/globalnews/status/14000952...
# name                                                    Globalnews.ca
# nlikes                                                             18
# nreplies                                                            2
# nretweets                                                           1
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               Wednesday marks the third straight day Ontario...
# twitter_handle                                             globalnews
# urls                                        [https://trib.al/hj7CzMC]
# username                                                   globalnews
# video                                                               0
# run_time                                          2021-06-02 16:02:48
# time_since_tweet                                            41.216667
# total                                                              21
# average_nreactions                                               68.0
# cut_off                                                          54.4
#
#                                                                   118  \
# conversation_id                                   1400097129322844171
# date                                                    1622647742000
# hashtags                                                           []
# id                                                1400097129322844171
# language                                                           en
# link                https://twitter.com/Gizmodo/status/14000971293...
# name                                                          Gizmodo
# nlikes                                                              6
# nreplies                                                            1
# nretweets                                                           1
# photos                                                             []
# retweet                                                         False
# source
# thumbnail
# tweet               Please Give All the Awards to This Mind-Meltin...
# twitter_handle                                                Gizmodo
# urls                                          [http://dlvr.it/S0wV1x]
# username                                                      Gizmodo
# video                                                               0
# run_time                                          2021-06-02 16:02:48
# time_since_tweet                                            33.766667
# total                                                               8
# average_nreactions                                          82.666667
# cut_off                                                     66.133333
#
#                                                                   119
# conversation_id                                   1400094854311337987
# date                                                    1622647200000
# hashtags                                                           []
# id                                                1400094854311337987
# language                                                           en
# link                https://twitter.com/PulseGhana/status/14000948...
# name                                                      Pulse Ghana
# nlikes                                                             32
# nreplies                                                            2
# nretweets                                                           2
# photos              [https://pbs.twimg.com/media/E24gtJLXwAIxqQ6.jpg]
# retweet                                                         False
# source
# thumbnail             https://pbs.twimg.com/media/E24gtJLXwAIxqQ6.jpg
# tweet               Man jailed 9 months for beating stranger who s...
# twitter_handle                                             pulseghana
# urls                                         [https://bit.ly/34BRLlA]
# username                                                   PulseGhana
# video                                                               1
# run_time                                          2021-06-02 16:02:48
# time_since_tweet                                                 42.8
# total                                                              36
# average_nreactions                                         109.538462
# cut_off                                                     87.630769
#
# [24 rows x 120 columns]

# %%
records = new_df_2.to_dict("records")

# %%
with open('person.json', 'a+') as json_file:
        json.dump(records, json_file)

# %%
import json


for record in records:
    with open('person.json', 'a+') as json_file:
        json.dump(record, json_file)

# %%
new_df_2['date'] = new_df_2['date'].astype(str)

# %%
records
# Out:
# [{'conversation_id': '1400095572082761730',
#   'date': '2021-06-02 15:22:51',
#   'hashtags': [],
#   'id': '1400095572082761730',
#   'language': 'en',
#   'link': 'https://twitter.com/GazetteNGR/status/1400095572082761730',
#   'name': 'Peoples Gazette',
#   'nlikes': 36,
#   'nreplies': 5,
#   'nretweets': 19,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Bill to end HND-Bachelors degree dichotomy passed  https://t.co/jSGnOokIIY',
#   'twitter_handle': 'gazettengr',
#   'urls': ['https://gazettengr.com/bill-to-end-hnd-bachelors-degree-dichotomy-passed/?utm_source=ReviveOldPost&utm_medium=social&utm_campaign=ReviveOldPost'],
#   'username': 'GazetteNGR',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 39.95,
#   'total': 60,
#   'average_nreactions': 116.64285714285714,
#   'cut_off': 93.31428571428572},
#  {'conversation_id': '1400097495976456192',
#   'date': '2021-06-02 15:30:30',
#   'hashtags': [],
#   'id': '1400097495976456192',
#   'language': 'en',
#   'link': 'https://twitter.com/politico/status/1400097495976456192',
#   'name': 'POLITICO',
#   'nlikes': 18,
#   'nreplies': 11,
#   'nretweets': 8,
#   'photos': ['https://pbs.twimg.com/media/E24lQNfXMAEimTJ.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24lQNfXMAEimTJ.jpg',
#   'tweet': 'The military’s “wish lists” outline needs for more aircraft, helos and ships if Congress boosts the defense budget  https://t.co/BhuHBQxEv2  https://t.co/rGmX0d1ZlN',
#   'twitter_handle': 'politico',
#   'urls': ['https://politi.co/3vWYWRv'],
#   'username': 'politico',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 32.3,
#   'total': 37,
#   'average_nreactions': 149.5,
#   'cut_off': 119.6},
#  {'conversation_id': '1400097934327402500',
#   'date': '2021-06-02 15:32:14',
#   'hashtags': [],
#   'id': '1400097934327402500',
#   'language': 'en',
#   'link': 'https://twitter.com/BreitbartNews/status/1400097934327402500',
#   'name': 'Breitbart News',
#   'nlikes': 38,
#   'nreplies': 16,
#   'nretweets': 10,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Good grief.  https://t.co/R355kibJeZ',
#   'twitter_handle': 'breitbartnews',
#   'urls': ['https://trib.al/5gnGVjN'],
#   'username': 'BreitbartNews',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 30.566666666666666,
#   'total': 64,
#   'average_nreactions': 498.8333333333333,
#   'cut_off': 399.06666666666666},
#  {'conversation_id': '1400096078465208325',
#   'date': '2021-06-02 15:24:52',
#   'hashtags': [],
#   'id': '1400096078465208325',
#   'language': 'en',
#   'link': 'https://twitter.com/CTVNews/status/1400096078465208325',
#   'name': 'CTV News',
#   'nlikes': 11,
#   'nreplies': 7,
#   'nretweets': 7,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Deaths from COVID-19 reduced Canadian life expectancy at birth by 0.41 years, Statistics Canada estimates  https://t.co/ftK9Nki8nL',
#   'twitter_handle': 'ctvnews',
#   'urls': ['https://www.ctvnews.ca/health/coronavirus/pandemic-cut-short-canadian-life-expectancy-by-5-months-statcan-says-1.5452901'],
#   'username': 'CTVNews',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 37.93333333333333,
#   'total': 25,
#   'average_nreactions': 100.875,
#   'cut_off': 80.7},
#  {'conversation_id': '1400096140809342984',
#   'date': '2021-06-02 15:25:07',
#   'hashtags': [],
#   'id': '1400096140809342984',
#   'language': 'en',
#   'link': 'https://twitter.com/CTVNews/status/1400096140809342984',
#   'name': 'CTV News',
#   'nlikes': 34,
#   'nreplies': 1,
#   'nretweets': 8,
#   'photos': ['https://pbs.twimg.com/media/E24kBTLXEAABO3L.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24kBTLXEAABO3L.jpg',
#   'tweet': 'MLB recognizes Lou Gehrig Day for ALS Awareness Month  https://t.co/lKxwi5545M  https://t.co/t6o7QIFj3h',
#   'twitter_handle': 'ctvnews',
#   'urls': ['http://bit.ly/3uDAz9S'],
#   'username': 'CTVNews',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 37.68333333333333,
#   'total': 43,
#   'average_nreactions': 100.875,
#   'cut_off': 80.7},
#  {'conversation_id': '1400097435138015235',
#   'date': '2021-06-02 15:30:15',
#   'hashtags': [],
#   'id': '1400097435138015235',
#   'language': 'en',
#   'link': 'https://twitter.com/CTVNews/status/1400097435138015235',
#   'name': 'CTV News',
#   'nlikes': 1,
#   'nreplies': 0,
#   'nretweets': 1,
#   'photos': ['https://pbs.twimg.com/media/E24lMndWEAAqp3Q.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24lMndWEAAqp3Q.jpg',
#   'tweet': 'Zverev keeps it short, advances to 3rd round at French Open  https://t.co/uZqk9Gl63m  https://t.co/efVXtrHsKQ',
#   'twitter_handle': 'ctvnews',
#   'urls': ['https://www.ctvnews.ca/sports/zverev-keeps-it-short-advances-to-3rd-round-at-french-open-1.5452837?cid=sm%3Atrueanthem%3A%7B%7Bcampaignname%7D%7D%3Atwitterpost%E2%80%8B&taid=60b795f7ca44bd000180bebd&utm_campaign=trueAnthem%3A+Trending+Content&utm_medium=trueAnthem&utm_source=twitter'],
#   'username': 'CTVNews',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 32.55,
#   'total': 2,
#   'average_nreactions': 100.875,
#   'cut_off': 80.7},
#  {'conversation_id': '1400095190099111943',
#   'date': '2021-06-02 15:21:20',
#   'hashtags': [],
#   'id': '1400095190099111943',
#   'language': 'en',
#   'link': 'https://twitter.com/CTVNews/status/1400095190099111943',
#   'name': 'CTV News',
#   'nlikes': 27,
#   'nreplies': 0,
#   'nretweets': 3,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "'We want to see them together as long as possible': Pair of old wild dogs reunited by Alberta rescue group  https://t.co/S0TXOuBQab",
#   'twitter_handle': 'ctvnews',
#   'urls': ['https://calgary.ctvnews.ca/we-want-to-see-them-together-as-long-as-possible-pair-of-old-wild-dogs-reunited-by-alberta-rescue-group-1.5452422'],
#   'username': 'CTVNews',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 41.46666666666667,
#   'total': 30,
#   'average_nreactions': 100.875,
#   'cut_off': 80.7},
#  {'conversation_id': '1400096264226672641',
#   'date': '2021-06-02 15:25:36',
#   'hashtags': [],
#   'id': '1400096264226672641',
#   'language': 'en',
#   'link': 'https://twitter.com/IndianExpress/status/1400096264226672641',
#   'name': 'The Indian Express',
#   'nlikes': 19,
#   'nreplies': 0,
#   'nretweets': 2,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'According to the police, the accused was shot in the leg while a head constable also sustained injuries.  https://t.co/hdKTwCWQu3',
#   'twitter_handle': 'indianexpress',
#   'urls': ['https://bit.ly/3vLQPH1'],
#   'username': 'IndianExpress',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 37.2,
#   'total': 21,
#   'average_nreactions': 102.88888888888889,
#   'cut_off': 82.3111111111111},
#  {'conversation_id': '1400097203725783042',
#   'date': '2021-06-02 15:29:20',
#   'hashtags': [],
#   'id': '1400097203725783042',
#   'language': 'en',
#   'link': 'https://twitter.com/vanguardngrnews/status/1400097203725783042',
#   'name': 'Vanguard Newspapers',
#   'nlikes': 42,
#   'nreplies': 21,
#   'nretweets': 22,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "JUST IN: DSS arrests gov's aide for inciting Nigerians against Buhari   https://t.co/QWT2GbrEDf",
#   'twitter_handle': 'vanguardngrnews',
#   'urls': ['https://community.vanguardngr.com/forum/topics/just-in-dss-arrests-gov-s-aide-for-inciting-nigerians-against'],
#   'username': 'vanguardngrnews',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 33.46666666666667,
#   'total': 85,
#   'average_nreactions': 113.2608695652174,
#   'cut_off': 90.60869565217392},
#  {'conversation_id': '1400095420349485060',
#   'date': '2021-06-02 15:22:15',
#   'hashtags': ['vanguardnews'],
#   'id': '1400095420349485060',
#   'language': 'en',
#   'link': 'https://twitter.com/vanguardngrnews/status/1400095420349485060',
#   'name': 'Vanguard Newspapers',
#   'nlikes': 29,
#   'nreplies': 7,
#   'nretweets': 11,
#   'photos': ['https://pbs.twimg.com/media/E24jXWtVkAUD3rc.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24jXWtVkAUD3rc.jpg',
#   'tweet': '2023: Reconsider your ambition, allow Osinbajo to contest, APC Group tells Tinubu  https://t.co/zx12eq3MTy #vanguardnews  https://t.co/52nH1oXr9d',
#   'twitter_handle': 'vanguardngrnews',
#   'urls': ['https://www.vanguardngr.com/2021/06/2023-reconsider-your-ambition-allow-osinbajo-to-contest-apc-group-tells-tinubu/?utm_source=dlvr.it&utm_medium=twitter'],
#   'username': 'vanguardngrnews',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 40.55,
#   'total': 47,
#   'average_nreactions': 113.2608695652174,
#   'cut_off': 90.60869565217392},
#  {'conversation_id': '1400095398606172161',
#   'date': '2021-06-02 15:22:10',
#   'hashtags': ['vanguardnews'],
#   'id': '1400095398606172161',
#   'language': 'en',
#   'link': 'https://twitter.com/vanguardngrnews/status/1400095398606172161',
#   'name': 'Vanguard Newspapers',
#   'nlikes': 18,
#   'nreplies': 6,
#   'nretweets': 2,
#   'photos': ['https://pbs.twimg.com/media/E24jWEqUcAQK7wi.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24jWEqUcAQK7wi.jpg',
#   'tweet': 'A look at Buhari’s hailers and his haters  https://t.co/uTS3NfoXPA #vanguardnews  https://t.co/98nGd28vFA',
#   'twitter_handle': 'vanguardngrnews',
#   'urls': ['https://www.vanguardngr.com/2021/06/a-look-at-buharis-hailers-and-his-haters/?utm_source=dlvr.it&utm_medium=twitter'],
#   'username': 'vanguardngrnews',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 40.63333333333333,
#   'total': 26,
#   'average_nreactions': 113.2608695652174,
#   'cut_off': 90.60869565217392},
#  {'conversation_id': '1400095434484314113',
#   'date': '2021-06-02 15:22:18',
#   'hashtags': ['vanguardnews'],
#   'id': '1400095434484314113',
#   'language': 'en',
#   'link': 'https://twitter.com/vanguardngrnews/status/1400095434484314113',
#   'name': 'Vanguard Newspapers',
#   'nlikes': 15,
#   'nreplies': 4,
#   'nretweets': 7,
#   'photos': ['https://pbs.twimg.com/media/E24jYLEVEAcPNI9.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24jYLEVEAcPNI9.jpg',
#   'tweet': 'JTF arrests 10 suspects over attacks on security formations in Akwa Ibom  https://t.co/ioSuCVqfNq #vanguardnews  https://t.co/6jpGYroWTx',
#   'twitter_handle': 'vanguardngrnews',
#   'urls': ['https://www.vanguardngr.com/2021/06/jtf-arrests-10-suspects-over-attacks-on-security-formations-in-akwa-ibom/?utm_source=dlvr.it&utm_medium=twitter'],
#   'username': 'vanguardngrnews',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 40.5,
#   'total': 26,
#   'average_nreactions': 113.2608695652174,
#   'cut_off': 90.60869565217392},
#  {'conversation_id': '1400095409821798402',
#   'date': '2021-06-02 15:22:12',
#   'hashtags': ['vanguardnews'],
#   'id': '1400095409821798402',
#   'language': 'en',
#   'link': 'https://twitter.com/vanguardngrnews/status/1400095409821798402',
#   'name': 'Vanguard Newspapers',
#   'nlikes': 21,
#   'nreplies': 1,
#   'nretweets': 3,
#   'photos': ['https://pbs.twimg.com/media/E24jWwMUUAElLtc.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24jWwMUUAElLtc.jpg',
#   'tweet': 'LASG pays over N32bn to 7,998 retirees in 2 years  https://t.co/a2WyDdy58n #vanguardnews  https://t.co/9RgmEaxLDr',
#   'twitter_handle': 'vanguardngrnews',
#   'urls': ['https://www.vanguardngr.com/2021/06/lasg-pays-over-n32bn-to-7998-retirees-in-2-years/?utm_source=dlvr.it&utm_medium=twitter'],
#   'username': 'vanguardngrnews',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 40.6,
#   'total': 25,
#   'average_nreactions': 113.2608695652174,
#   'cut_off': 90.60869565217392},
#  {'conversation_id': '1400095385473798144',
#   'date': '2021-06-02 15:22:07',
#   'hashtags': ['vanguardnews'],
#   'id': '1400095385473798144',
#   'language': 'en',
#   'link': 'https://twitter.com/vanguardngrnews/status/1400095385473798144',
#   'name': 'Vanguard Newspapers',
#   'nlikes': 5,
#   'nreplies': 1,
#   'nretweets': 0,
#   'photos': ['https://pbs.twimg.com/media/E24jVVrVIAUNu8v.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24jVVrVIAUNu8v.jpg',
#   'tweet': 'How Josephine Oboh-Macleod wields art as tool to reduce racism, classism  https://t.co/ynwcyWYT0d #vanguardnews  https://t.co/D2zmbwkxg2',
#   'twitter_handle': 'vanguardngrnews',
#   'urls': ['https://www.vanguardngr.com/2021/06/how-josephine-oboh-macleod-wields-art-as-tool-to-reduce-racism-classism/?utm_source=dlvr.it&utm_medium=twitter'],
#   'username': 'vanguardngrnews',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 40.68333333333333,
#   'total': 6,
#   'average_nreactions': 113.2608695652174,
#   'cut_off': 90.60869565217392},
#  {'conversation_id': '1400095426968100868',
#   'date': '2021-06-02 15:22:16',
#   'hashtags': ['vanguardnews'],
#   'id': '1400095426968100868',
#   'language': 'en',
#   'link': 'https://twitter.com/vanguardngrnews/status/1400095426968100868',
#   'name': 'Vanguard Newspapers',
#   'nlikes': 11,
#   'nreplies': 0,
#   'nretweets': 3,
#   'photos': ['https://pbs.twimg.com/media/E24jXvXVcAEFDLv.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24jXvXVcAEFDLv.jpg',
#   'tweet': 'FG assures commitment to implement 2020 zonal intervention, constituency projects  https://t.co/GeGQZFuOaG #vanguardnews  https://t.co/ynPaz2PEoM',
#   'twitter_handle': 'vanguardngrnews',
#   'urls': ['https://www.vanguardngr.com/2021/06/fg-assures-commitment-to-implement-2020-zonal-intervention-constituency-projects/?utm_source=dlvr.it&utm_medium=twitter'],
#   'username': 'vanguardngrnews',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 40.53333333333333,
#   'total': 14,
#   'average_nreactions': 113.2608695652174,
#   'cut_off': 90.60869565217392},
#  {'conversation_id': '1400097135580925954',
#   'date': '2021-06-02 15:29:04',
#   'hashtags': [],
#   'id': '1400097135580925954',
#   'language': 'en',
#   'link': 'https://twitter.com/WIRED/status/1400097135580925954',
#   'name': 'WIRED',
#   'nlikes': 46,
#   'nreplies': 0,
#   'nretweets': 17,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'VR therapy is giving OCD patients the courage to face their fears.  https://t.co/RmsXcso1I7',
#   'twitter_handle': 'WIRED',
#   'urls': ['https://wired.trib.al/xrHEQuh'],
#   'username': 'WIRED',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 33.733333333333334,
#   'total': 63,
#   'average_nreactions': 216.84615384615384,
#   'cut_off': 173.47692307692307},
#  {'conversation_id': '1400097407455670272',
#   'date': '2021-06-02 15:30:09',
#   'hashtags': [],
#   'id': '1400097407455670272',
#   'language': 'en',
#   'link': 'https://twitter.com/mashable/status/1400097407455670272',
#   'name': 'Mashable',
#   'nlikes': 5,
#   'nreplies': 0,
#   'nretweets': 3,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "Big love for 'The Bold Type' — save for one tiny change we wish we could make.  https://t.co/mFxHn1JJOO",
#   'twitter_handle': 'mashable',
#   'urls': ['https://mashable.com/article/the-bold-type-media-industry/?taid=60b795f1ca44bd000180beb2&utm_campaign=trueAnthem%3A+Trending+Content&utm_medium=trueAnthem&utm_source=twitter'],
#   'username': 'mashable',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 32.65,
#   'total': 8,
#   'average_nreactions': 83.0,
#   'cut_off': 66.4},
#  {'conversation_id': '1400094876474167301',
#   'date': '2021-06-02 15:20:05',
#   'hashtags': [],
#   'id': '1400094876474167301',
#   'language': 'en',
#   'link': 'https://twitter.com/mashable/status/1400094876474167301',
#   'name': 'Mashable',
#   'nlikes': 13,
#   'nreplies': 0,
#   'nretweets': 6,
#   'photos': ['https://pbs.twimg.com/media/E24i3qvXEAAVx9h.png'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24i3qvXEAAVx9h.png',
#   'tweet': 'Lyft redesigns its electric bicycle with built-in screen and speakers  https://t.co/zqXg7kBsfb  https://t.co/ZziUFrMifa',
#   'twitter_handle': 'mashable',
#   'urls': ['https://mashable.com/article/lyft-new-electric-bicycle/'],
#   'username': 'mashable',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 42.71666666666667,
#   'total': 19,
#   'average_nreactions': 83.0,
#   'cut_off': 66.4},
#  {'conversation_id': '1400095774831222800',
#   'date': '2021-06-02 15:23:39',
#   'hashtags': [],
#   'id': '1400095774831222800',
#   'language': 'en',
#   'link': 'https://twitter.com/verge/status/1400095774831222800',
#   'name': 'The Verge',
#   'nlikes': 215,
#   'nreplies': 16,
#   'nretweets': 26,
#   'photos': ['https://pbs.twimg.com/media/E24jr-SWQAQ_kZk.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24jr-SWQAQ_kZk.jpg',
#   'tweet': 'Nintendo’s E3 event will be "focused exclusively" on Switch games  https://t.co/aYVJUhPnTJ  https://t.co/poFezk7MBg',
#   'twitter_handle': 'verge',
#   'urls': ['https://www.theverge.com/2021/6/2/22464828/nintendo-e3-event-june-15th-software-exclusive?utm_campaign=theverge&utm_content=chorus&utm_medium=social&utm_source=twitter'],
#   'username': 'verge',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 39.15,
#   'total': 257,
#   'average_nreactions': 139.95652173913044,
#   'cut_off': 111.96521739130435},
#  {'conversation_id': '1400094876881068033',
#   'date': '2021-06-02 15:20:05',
#   'hashtags': [],
#   'id': '1400094876881068033',
#   'language': 'en',
#   'link': 'https://twitter.com/DailyMailUK/status/1400094876881068033',
#   'name': 'Daily Mail U.K.',
#   'nlikes': 9,
#   'nreplies': 6,
#   'nretweets': 2,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "Naomi Osaka WON'T be given special treatment at Wimbledon this month  https://t.co/pWqYE6Qk7F",
#   'twitter_handle': 'dailymailuk',
#   'urls': ['https://trib.al/3TVyc39'],
#   'username': 'DailyMailUK',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 42.71666666666667,
#   'total': 17,
#   'average_nreactions': 104.375,
#   'cut_off': 83.5},
#  {'conversation_id': '1400097389407576071',
#   'date': '2021-06-02 15:30:04',
#   'hashtags': [],
#   'id': '1400097389407576071',
#   'language': 'en',
#   'link': 'https://twitter.com/DailyMailUK/status/1400097389407576071',
#   'name': 'Daily Mail U.K.',
#   'nlikes': 6,
#   'nreplies': 1,
#   'nretweets': 2,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "Double murder suspect 'knifed to death his ex-partner and her 'football mad' autistic son, nine'  https://t.co/QMBuwdkJVe",
#   'twitter_handle': 'dailymailuk',
#   'urls': ['https://trib.al/G3kLBu7'],
#   'username': 'DailyMailUK',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 32.733333333333334,
#   'total': 9,
#   'average_nreactions': 104.375,
#   'cut_off': 83.5},
#  {'conversation_id': '1400094874335055881',
#   'date': '2021-06-02 15:20:05',
#   'hashtags': [],
#   'id': '1400094874335055881',
#   'language': 'en',
#   'link': 'https://twitter.com/HarvardBiz/status/1400094874335055881',
#   'name': 'Harvard Business Review',
#   'nlikes': 46,
#   'nreplies': 1,
#   'nretweets': 5,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Lesson #1: Hire board members for competence and objectivity. On issues where the board lacks expertise, bring experts in to help you.  https://t.co/UymQlm4vz6',
#   'twitter_handle': 'HarvardBiz',
#   'urls': ['https://hbr.org/2021/06/what-corporate-boards-can-learn-from-boeings-mistakes?utm_campaign=hbr&utm_medium=social&utm_source=twitter'],
#   'username': 'HarvardBiz',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 42.71666666666667,
#   'total': 52,
#   'average_nreactions': 129.67391304347825,
#   'cut_off': 103.7391304347826},
#  {'conversation_id': '1400097415567446017',
#   'date': '2021-06-02 15:30:11',
#   'hashtags': [],
#   'id': '1400097415567446017',
#   'language': 'en',
#   'link': 'https://twitter.com/CNN/status/1400097415567446017',
#   'name': 'CNN',
#   'nlikes': 266,
#   'nreplies': 59,
#   'nretweets': 65,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Pope Francis has issued the most extensive revision to Catholic Church law in four decades, insisting that bishops take action against clerics who abuse minors and vulnerable adults, commit fraud or attempt to ordain women.  https://t.co/AUgZ46SZ8z',
#   'twitter_handle': 'cnn',
#   'urls': ['https://cnn.it/3uL6GVd'],
#   'username': 'CNN',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 32.61666666666667,
#   'total': 390,
#   'average_nreactions': 434.0810810810811,
#   'cut_off': 347.2648648648649},
#  {'conversation_id': '1400097886298378246',
#   'date': '2021-06-02 15:32:03',
#   'hashtags': [],
#   'id': '1400097886298378246',
#   'language': 'en',
#   'link': 'https://twitter.com/engadget/status/1400097886298378246',
#   'name': 'Engadget',
#   'nlikes': 24,
#   'nreplies': 0,
#   'nretweets': 3,
#   'photos': ['https://pbs.twimg.com/media/E24lm4QWEAAfBm6.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24lm4QWEAAfBm6.jpg',
#   'tweet': 'The E3 Nintendo Direct will take place on June 15th  https://t.co/w13XSr9BQt  https://t.co/o0iStTa6Zp',
#   'twitter_handle': 'engadget',
#   'urls': ['https://engt.co/2TDyjmb'],
#   'username': 'engadget',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 30.75,
#   'total': 27,
#   'average_nreactions': 86.0,
#   'cut_off': 68.8},
#  {'conversation_id': '1400097059349356547',
#   'date': '2021-06-02 15:28:46',
#   'hashtags': [],
#   'id': '1400097059349356547',
#   'language': 'en',
#   'link': 'https://twitter.com/TorontoStar/status/1400097059349356547',
#   'name': 'Toronto Star',
#   'nlikes': 18,
#   'nreplies': 9,
#   'nretweets': 8,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': '⚡️Premier Doug Ford to officially announce no in-class learning until September  Story by @krushowy and @robertbenzie   https://t.co/HYKuhX6NZn',
#   'twitter_handle': 'torontostar',
#   'urls': ['https://twitter.com/i/events/1400093378306584577'],
#   'username': 'TorontoStar',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 34.03333333333333,
#   'total': 35,
#   'average_nreactions': 94.0,
#   'cut_off': 75.2},
#  {'conversation_id': '1400096296006979586',
#   'date': '2021-06-02 15:25:44',
#   'hashtags': [],
#   'id': '1400096296006979586',
#   'language': 'en',
#   'link': 'https://twitter.com/BusinessInsider/status/1400096296006979586',
#   'name': 'Business Insider',
#   'nlikes': 43,
#   'nreplies': 1,
#   'nretweets': 14,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Dogecoin leaps 41% as Coinbase Pro network begins to accept transfers of the meme currency  https://t.co/8iozj1uByu',
#   'twitter_handle': 'BusinessInsider',
#   'urls': ['http://www.businessinsider.com/dogecoin-price-today-doge-coinbase-pro-transfer-network-cryptocurrency-meme-2021-6'],
#   'username': 'BusinessInsider',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 37.06666666666667,
#   'total': 58,
#   'average_nreactions': 107.5,
#   'cut_off': 86.0},
#  {'conversation_id': '1400095328813129730',
#   'date': '2021-06-02 15:21:53',
#   'hashtags': [],
#   'id': '1400095328813129730',
#   'language': 'en',
#   'link': 'https://twitter.com/CBSNews/status/1400095328813129730',
#   'name': 'CBS News',
#   'nlikes': 47,
#   'nreplies': 57,
#   'nretweets': 31,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/amplify_video_thumb/1400095295841652739/img/rLacsLACj9Ik44lZ.jpg',
#   'tweet': 'China reported the world\'s first known human infection from the H10N3 bird flu strain in a 41-year-old man, but said the risk of it spreading widely among people was "extremely low."  https://t.co/oKVcBVoLWg  https://t.co/PG5Kd2TVHw',
#   'twitter_handle': 'cbsnews',
#   'urls': ['https://cbsn.ws/3uKtN1S'],
#   'username': 'CBSNews',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 40.916666666666664,
#   'total': 135,
#   'average_nreactions': 152.0,
#   'cut_off': 121.6},
#  {'conversation_id': '1400094761684512773',
#   'date': '2021-06-02 15:19:38',
#   'hashtags': [],
#   'id': '1400094761684512773',
#   'language': 'en',
#   'link': 'https://twitter.com/CBSNews/status/1400094761684512773',
#   'name': 'CBS News',
#   'nlikes': 34,
#   'nreplies': 7,
#   'nretweets': 15,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Amazon workers have highest warehouse injury rate, labor groups say   https://t.co/wqAhpB5AGX',
#   'twitter_handle': 'cbsnews',
#   'urls': ['https://cbsn.ws/3i7Tnvj'],
#   'username': 'CBSNews',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 43.166666666666664,
#   'total': 56,
#   'average_nreactions': 152.0,
#   'cut_off': 121.6},
#  {'conversation_id': '1400097865922383875',
#   'date': '2021-06-02 15:31:58',
#   'hashtags': [],
#   'id': '1400097865922383875',
#   'language': 'en',
#   'link': 'https://twitter.com/MarketWatch/status/1400097865922383875',
#   'name': 'MarketWatch',
#   'nlikes': 25,
#   'nreplies': 9,
#   'nretweets': 14,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Elon Musk’s Twitter usage has twice violated a court order requiring his tweets be vetted by Tesla’s lawyers, The Wall Street Journal reported late on Tuesday.  https://t.co/JedXMmc42d',
#   'twitter_handle': 'marketwatch',
#   'urls': ['https://on.mktw.net/3pbBhdr'],
#   'username': 'MarketWatch',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 30.833333333333332,
#   'total': 48,
#   'average_nreactions': 80.66666666666667,
#   'cut_off': 64.53333333333333},
#  {'conversation_id': '1400094581904101376',
#   'date': '2021-06-02 15:18:55',
#   'hashtags': [],
#   'id': '1400094581904101376',
#   'language': 'en',
#   'link': 'https://twitter.com/MarketWatch/status/1400094581904101376',
#   'name': 'MarketWatch',
#   'nlikes': 4,
#   'nreplies': 3,
#   'nretweets': 3,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Meat-producer stocks mixed in wake of ransomware attack against JBS  https://t.co/k6oHEZ0qLc',
#   'twitter_handle': 'marketwatch',
#   'urls': ['https://on.mktw.net/3ij57ei'],
#   'username': 'MarketWatch',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 43.88333333333333,
#   'total': 10,
#   'average_nreactions': 80.66666666666667,
#   'cut_off': 64.53333333333333},
#  {'conversation_id': '1400097137560592389',
#   'date': '2021-06-02 15:29:04',
#   'hashtags': [],
#   'id': '1400097137560592389',
#   'language': 'en',
#   'link': 'https://twitter.com/BBCWorld/status/1400097137560592389',
#   'name': 'BBC News (World)',
#   'nlikes': 198,
#   'nreplies': 20,
#   'nretweets': 62,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Tesla failed to stop Musk tweets, says regulator  https://t.co/GkJVlSVdm6',
#   'twitter_handle': 'bbcworld',
#   'urls': ['https://bbc.in/3fFBUJ4'],
#   'username': 'BBCWorld',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 33.733333333333334,
#   'total': 280,
#   'average_nreactions': 344.68333333333334,
#   'cut_off': 275.74666666666667},
#  {'conversation_id': '1400097004349427715',
#   'date': '2021-06-02 15:28:33',
#   'hashtags': [],
#   'id': '1400097004349427715',
#   'language': 'en',
#   'link': 'https://twitter.com/nypost/status/1400097004349427715',
#   'name': 'New York Post',
#   'nlikes': 151,
#   'nreplies': 54,
#   'nretweets': 42,
#   'photos': ['https://pbs.twimg.com/media/E24kzlbWEAEh-gU.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24kzlbWEAEh-gU.jpg',
#   'tweet': 'Iranian navy ship catches fire, sinks mysteriously in Gulf of Oman  https://t.co/8qjf6oC4G2  https://t.co/HNn5B7mIYg',
#   'twitter_handle': 'nypost',
#   'urls': ['https://trib.al/gDagXzE'],
#   'username': 'nypost',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 34.25,
#   'total': 247,
#   'average_nreactions': 173.26857142857142,
#   'cut_off': 138.61485714285715},
#  {'conversation_id': '1400095324413304833',
#   'date': '2021-06-02 15:21:52',
#   'hashtags': [],
#   'id': '1400095324413304833',
#   'language': 'en',
#   'link': 'https://twitter.com/nypost/status/1400095324413304833',
#   'name': 'New York Post',
#   'nlikes': 9,
#   'nreplies': 5,
#   'nretweets': 3,
#   'photos': ['https://pbs.twimg.com/media/E24jRu3XEAM1xRW.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24jRu3XEAM1xRW.jpg',
#   'tweet': 'Danny Ainge considering Celtics divorce after disastrous season  https://t.co/Bdsg0wxFvd  https://t.co/KL5ohmc4V8',
#   'twitter_handle': 'nypost',
#   'urls': ['https://trib.al/eTTPQUL'],
#   'username': 'nypost',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 40.93333333333333,
#   'total': 17,
#   'average_nreactions': 173.26857142857142,
#   'cut_off': 138.61485714285715},
#  {'conversation_id': '1400095306642083840',
#   'date': '2021-06-02 15:21:48',
#   'hashtags': [],
#   'id': '1400095306642083840',
#   'language': 'en',
#   'link': 'https://twitter.com/nypost/status/1400095306642083840',
#   'name': 'New York Post',
#   'nlikes': 44,
#   'nreplies': 3,
#   'nretweets': 12,
#   'photos': ['https://pbs.twimg.com/media/E24jQwZWEAAhfys.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24jQwZWEAAhfys.jpg',
#   'tweet': 'Earlier sleep cycles linked to lower depression risk: study  https://t.co/0Ef8l0OOkH  https://t.co/JOWM2ekslF',
#   'twitter_handle': 'nypost',
#   'urls': ['https://trib.al/LO10lfw'],
#   'username': 'nypost',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 41.0,
#   'total': 59,
#   'average_nreactions': 173.26857142857142,
#   'cut_off': 138.61485714285715},
#  {'conversation_id': '1400097432176889859',
#   'date': '2021-06-02 15:30:15',
#   'hashtags': [],
#   'id': '1400097432176889859',
#   'language': 'en',
#   'link': 'https://twitter.com/TMZ/status/1400097432176889859',
#   'name': 'TMZ',
#   'nlikes': 30,
#   'nreplies': 8,
#   'nretweets': 5,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "John Krasinski Reacts To Amy Schumer's Joke That Marriage To Emily Blunt Is 'For Publicity' (via @Fox411)  https://t.co/di1r6ptAcI",
#   'twitter_handle': 'tmz',
#   'urls': ['http://tmz.me/yhcXvAY'],
#   'username': 'TMZ',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 32.55,
#   'total': 43,
#   'average_nreactions': 122.56756756756756,
#   'cut_off': 98.05405405405405},
#  {'conversation_id': '1400097154773946368',
#   'date': '2021-06-02 15:29:08',
#   'hashtags': [],
#   'id': '1400097154773946368',
#   'language': 'en',
#   'link': 'https://twitter.com/CNET/status/1400097154773946368',
#   'name': 'CNET',
#   'nlikes': 18,
#   'nreplies': 1,
#   'nretweets': 8,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Alienware X Series x15, x17 super-slim gaming laptops available now, starting at $1,999  https://t.co/2k0ZhrFTuL',
#   'twitter_handle': 'CNET',
#   'urls': ['https://cnet.co/3g5h6td'],
#   'username': 'CNET',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 33.666666666666664,
#   'total': 27,
#   'average_nreactions': 82.5,
#   'cut_off': 66.0},
#  {'conversation_id': '1400094633166770176',
#   'date': '2021-06-02 15:19:07',
#   'hashtags': [],
#   'id': '1400094633166770176',
#   'language': 'en',
#   'link': 'https://twitter.com/BBCNews/status/1400094633166770176',
#   'name': 'BBC News (UK)',
#   'nlikes': 115,
#   'nreplies': 16,
#   'nretweets': 27,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "Plans to build world's deepest pool in Cornwall  https://t.co/paaxtRyFAr",
#   'twitter_handle': 'bbcnews',
#   'urls': ['https://bbc.in/3vKQRz6'],
#   'username': 'BBCNews',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 43.68333333333333,
#   'total': 158,
#   'average_nreactions': 169.0754716981132,
#   'cut_off': 135.26037735849056},
#  {'conversation_id': '1400096379725303809',
#   'date': '2021-06-02 15:26:04',
#   'hashtags': [],
#   'id': '1400096379725303809',
#   'language': 'en',
#   'link': 'https://twitter.com/BBCNews/status/1400096379725303809',
#   'name': 'BBC News (UK)',
#   'nlikes': 75,
#   'nreplies': 11,
#   'nretweets': 16,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Wildlife officers called in by the Ministry of Defence after badger dug its way into Army base  https://t.co/r94vnVxq4V',
#   'twitter_handle': 'bbcnews',
#   'urls': ['https://bbc.in/3fICyFH'],
#   'username': 'BBCNews',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 36.733333333333334,
#   'total': 102,
#   'average_nreactions': 169.0754716981132,
#   'cut_off': 135.26037735849056},
#  {'conversation_id': '1400096894152544256',
#   'date': '2021-06-02 15:28:06',
#   'hashtags': [],
#   'id': '1400096894152544256',
#   'language': 'en',
#   'link': 'https://twitter.com/people/status/1400096894152544256',
#   'name': 'People',
#   'nlikes': 78,
#   'nreplies': 1,
#   'nretweets': 11,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "Princess Diana's Wedding Dress (and 25-Foot Train!) Is on Display at Kensington Palace: See Photos\u200b   https://t.co/NIK0EnctoS",
#   'twitter_handle': 'people',
#   'urls': ['https://people.com/royals/princess-diana-wedding-dress-display-kensington-palace-royal-style-fashion-exhibit/?utm_campaign=peoplemagazine&utm_content=new&utm_medium=social&utm_source=twitter.com&utm_term=60b79576ca44bd000180beaf'],
#   'username': 'people',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 34.7,
#   'total': 90,
#   'average_nreactions': 126.41176470588236,
#   'cut_off': 101.12941176470589},
#  {'conversation_id': '1400095886001180681',
#   'date': '2021-06-02 15:24:06',
#   'hashtags': [],
#   'id': '1400095886001180681',
#   'language': 'en',
#   'link': 'https://twitter.com/people/status/1400095886001180681',
#   'name': 'People',
#   'nlikes': 36,
#   'nreplies': 1,
#   'nretweets': 8,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "Jimmy Fallon's New Picture Book Nana Loves You More Coming 2022\u200b   https://t.co/rv3NkUcwd6",
#   'twitter_handle': 'people',
#   'urls': ['https://people.com/parents/jimmy-fallon-new-picture-book-nana-loves-you-more-coming-2022-exclusive/?utm_campaign=peoplemagazine&utm_content=new&utm_medium=social&utm_source=twitter.com&utm_term=60b79486ca44bd000180bead'],
#   'username': 'people',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 38.7,
#   'total': 45,
#   'average_nreactions': 126.41176470588236,
#   'cut_off': 101.12941176470589},
#  {'conversation_id': '1400097902232539145',
#   'date': '2021-06-02 15:32:07',
#   'hashtags': [],
#   'id': '1400097902232539145',
#   'language': 'en',
#   'link': 'https://twitter.com/people/status/1400097902232539145',
#   'name': 'People',
#   'nlikes': 5,
#   'nreplies': 0,
#   'nretweets': 4,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Body Found at a Texas Motel in Search for Missing 6-Year-Old Boy\u200b   https://t.co/4PA4fg3Q8x',
#   'twitter_handle': 'people',
#   'urls': ['https://people.com/crime/body-found-at-a-texas-motel-in-search-for-missing-6-year-old-boy/?utm_campaign=peoplemagazine&utm_content=new&utm_medium=social&utm_source=twitter.com&utm_term=60b79666ca44bd000180bec0'],
#   'username': 'people',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 30.683333333333334,
#   'total': 9,
#   'average_nreactions': 126.41176470588236,
#   'cut_off': 101.12941176470589},
#  {'conversation_id': '1400094876453199882',
#   'date': '2021-06-02 15:20:05',
#   'hashtags': [],
#   'id': '1400094876453199882',
#   'language': 'en',
#   'link': 'https://twitter.com/people/status/1400094876453199882',
#   'name': 'People',
#   'nlikes': 21,
#   'nreplies': 0,
#   'nretweets': 9,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "Special Ed Teacher Who 'Went the Extra Mile' for Students Is Killed, and Family Says Suspect Is Ex\u200b   https://t.co/QYzTuss42Z",
#   'twitter_handle': 'people',
#   'urls': ['https://people.com/crime/special-ed-teacher-went-extra-mile-students-killed-family-says-suspect-ex/?utm_campaign=peoplemagazine&utm_content=new&utm_medium=social&utm_source=twitter.com&utm_term=60b79395ca44bd000180bea9'],
#   'username': 'people',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 42.71666666666667,
#   'total': 30,
#   'average_nreactions': 126.41176470588236,
#   'cut_off': 101.12941176470589},
#  {'conversation_id': '1400095281509720070',
#   'date': '2021-06-02 15:21:42',
#   'hashtags': [],
#   'id': '1400095281509720070',
#   'language': 'en',
#   'link': 'https://twitter.com/guardian/status/1400095281509720070',
#   'name': 'The Guardian',
#   'nlikes': 47,
#   'nreplies': 4,
#   'nretweets': 15,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Asthma warning as UK records hottest day of 2021 so far  https://t.co/NbKdpLCffB',
#   'twitter_handle': 'guardian',
#   'urls': ['https://www.theguardian.com/uk-news/2021/jun/02/thunderstorm-warnings-as-uk-records-hottest-day-of-2021-so-far?CMP=twt_gu&utm_source=Twitter&utm_medium#Echobox=1622643701'],
#   'username': 'guardian',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 41.1,
#   'total': 66,
#   'average_nreactions': 148.08527131782947,
#   'cut_off': 118.46821705426358},
#  {'conversation_id': '1400096499044913154',
#   'date': '2021-06-02 15:26:32',
#   'hashtags': [],
#   'id': '1400096499044913154',
#   'language': 'en',
#   'link': 'https://twitter.com/Independent/status/1400096499044913154',
#   'name': 'The Independent',
#   'nlikes': 23,
#   'nreplies': 6,
#   'nretweets': 10,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Trump agents reportedly spending thousands of dollars a month on porta potties  https://t.co/tZE42i8CjH',
#   'twitter_handle': 'Independent',
#   'urls': ['https://www.independent.co.uk/news/world/americas/us-politics/trump-secret-service-porta-potties-b1858124.html?utm_content=Echobox&utm_medium=Social&utm_source=Twitter#Echobox=1622641924'],
#   'username': 'Independent',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 36.266666666666666,
#   'total': 39,
#   'average_nreactions': 94.6,
#   'cut_off': 75.67999999999999},
#  {'conversation_id': '1400092425058766848',
#   'date': '2021-06-02 15:28:51',
#   'hashtags': ['borisjohnson', 'uknews'],
#   'id': '1400097081738645510',
#   'language': 'en',
#   'link': 'https://twitter.com/Independent/status/1400097081738645510',
#   'name': 'The Independent',
#   'nlikes': 8,
#   'nreplies': 3,
#   'nretweets': 4,
#   'photos': ['https://pbs.twimg.com/media/E24koMWXMAAW-ug.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24koMWXMAAW-ug.jpg',
#   'tweet': '#BorisJohnson #UKNews   ⚫Boris Johnson has called on Nato allies to "stand together against threats from the East".  ⬇️FOLLOW LIVE   https://t.co/FeIwaKPqvt  https://t.co/hAhcJqKZhw',
#   'twitter_handle': 'Independent',
#   'urls': ['https://www.independent.co.uk/news/uk/politics/boris-johnson-brexit-news-live-b1858009.html'],
#   'username': 'Independent',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 33.95,
#   'total': 15,
#   'average_nreactions': 94.6,
#   'cut_off': 75.67999999999999},
#  {'conversation_id': '1400095078622842880',
#   'date': '2021-06-02 15:20:53',
#   'hashtags': [],
#   'id': '1400095078622842880',
#   'language': 'en',
#   'link': 'https://twitter.com/Independent/status/1400095078622842880',
#   'name': 'The Independent',
#   'nlikes': 10,
#   'nreplies': 1,
#   'nretweets': 6,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Christina Hendricks reflects on being asked bra questions during Mad Men fame  https://t.co/uPa2QYbBMP',
#   'twitter_handle': 'Independent',
#   'urls': ['https://www.independent.co.uk/arts-entertainment/tv/news/mad-men-christina-hendricks-bra-joan-b1858302.html?utm_content=Echobox&utm_medium=Social&utm_source=Twitter#Echobox=1622643429'],
#   'username': 'Independent',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 41.916666666666664,
#   'total': 17,
#   'average_nreactions': 94.6,
#   'cut_off': 75.67999999999999},
#  {'conversation_id': '1400097614729777156',
#   'date': '2021-06-02 15:30:58',
#   'hashtags': [],
#   'id': '1400097614729777156',
#   'language': 'en',
#   'link': 'https://twitter.com/Independent/status/1400097614729777156',
#   'name': 'The Independent',
#   'nlikes': 5,
#   'nreplies': 0,
#   'nretweets': 1,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': '✈️ The Independent’s Travel Correspondent @SimonCalder will answer your questions on travel live  Find out more below  https://t.co/rOzRkHTQpn',
#   'twitter_handle': 'Independent',
#   'urls': ['https://www.independent.co.uk/travel/news-and-advice/simon-calder-questions-green-list-b1858204.html?utm_content=Echobox&utm_medium=Social&utm_source=Twitter#Echobox=1622635174'],
#   'username': 'Independent',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 31.833333333333332,
#   'total': 6,
#   'average_nreactions': 94.6,
#   'cut_off': 75.67999999999999},
#  {'conversation_id': '1400095741733912578',
#   'date': '2021-06-02 15:23:32',
#   'hashtags': [],
#   'id': '1400095741733912578',
#   'language': 'en',
#   'link': 'https://twitter.com/nationalpost/status/1400095741733912578',
#   'name': 'National Post',
#   'nlikes': 15,
#   'nreplies': 7,
#   'nretweets': 2,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'U.S. to send Israel $1 billion to replenish Iron Dome missile defences, senator says   https://t.co/SrmmdR0hzF',
#   'twitter_handle': 'nationalpost',
#   'urls': ['https://nationalpost.com/news/u-s-senator-expects-u-s-to-send-more-funds-for-israels-iron-dome?utm_medium=Social&utm_source=Twitter#Echobox=1622643811-1'],
#   'username': 'nationalpost',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 39.266666666666666,
#   'total': 24,
#   'average_nreactions': 99.0,
#   'cut_off': 79.2},
#  {'conversation_id': '1400097618181738503',
#   'date': '2021-06-02 15:30:59',
#   'hashtags': ['autonews'],
#   'id': '1400097618181738503',
#   'language': 'en',
#   'link': 'https://twitter.com/nationalpost/status/1400097618181738503',
#   'name': 'National Post',
#   'nlikes': 8,
#   'nreplies': 1,
#   'nretweets': 1,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Burnaby RCMP charge twins with impaired driving, one after the other  https://t.co/0W1euB5Z6p — via @drivingdotca  #autonews',
#   'twitter_handle': 'nationalpost',
#   'urls': ['https://driving.ca/auto-news/crashes/identically-impaired-burnaby-rcmp-charge-twins-with-impaired-driving-one-after-the-other?utm_source=Twitter&utm_medium=organic&utm_campaign=driving_promo_AO#Echobox=1622637850-5'],
#   'username': 'nationalpost',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 31.816666666666666,
#   'total': 10,
#   'average_nreactions': 99.0,
#   'cut_off': 79.2},
#  {'conversation_id': '1400097522375348224',
#   'date': '2021-06-02 15:30:36',
#   'hashtags': [],
#   'id': '1400097522375348224',
#   'language': 'en',
#   'link': 'https://twitter.com/FoxNews/status/1400097522375348224',
#   'name': 'Fox News',
#   'nlikes': 306,
#   'nreplies': 102,
#   'nretweets': 46,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Virginia parents organize to fight critical race theory learning in classrooms  https://t.co/UeFd0ZHEoA',
#   'twitter_handle': 'foxnews',
#   'urls': ['https://www.foxnews.com/us/virginia-parents-organize-fight-crt-learning-classrooms'],
#   'username': 'FoxNews',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 32.2,
#   'total': 454,
#   'average_nreactions': 257.9375,
#   'cut_off': 206.35},
#  {'conversation_id': '1400095006954774530',
#   'date': '2021-06-02 15:20:36',
#   'hashtags': [],
#   'id': '1400095006954774530',
#   'language': 'en',
#   'link': 'https://twitter.com/FoxNews/status/1400095006954774530',
#   'name': 'Fox News',
#   'nlikes': 174,
#   'nreplies': 30,
#   'nretweets': 26,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Queen Elizabeth to celebrate Platinum Jubilee in 2022 with special holiday weekend  https://t.co/clmzIpD2jU',
#   'twitter_handle': 'foxnews',
#   'urls': ['https://www.foxnews.com/entertainment/queen-elizabeth-celebrate-platinum-jubilee-2022-britain'],
#   'username': 'FoxNews',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 42.2,
#   'total': 230,
#   'average_nreactions': 257.9375,
#   'cut_off': 206.35},
#  {'conversation_id': '1400096124434796549',
#   'date': '2021-06-02 15:25:03',
#   'hashtags': [],
#   'id': '1400096124434796549',
#   'language': 'en',
#   'link': 'https://twitter.com/Inc/status/1400096124434796549',
#   'name': 'Inc.',
#   'nlikes': 19,
#   'nreplies': 1,
#   'nretweets': 7,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "Enhancing your customers' emotions is crucial.  https://t.co/iAmMvE5Pmu",
#   'twitter_handle': 'Inc',
#   'urls': ['http://on.inc.com/jJD5K3I'],
#   'username': 'Inc',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 37.75,
#   'total': 27,
#   'average_nreactions': 86.36363636363636,
#   'cut_off': 69.0909090909091},
#  {'conversation_id': '1400094649612599302',
#   'date': '2021-06-02 15:19:11',
#   'hashtags': [],
#   'id': '1400094649612599302',
#   'language': 'en',
#   'link': 'https://twitter.com/9to5mac/status/1400094649612599302',
#   'name': '9to5Mac.com',
#   'nlikes': 70,
#   'nreplies': 4,
#   'nretweets': 14,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "It's not just you, Apple confirms Apple Card outage affecting all users  https://t.co/z2YbbJRypD by @michaelpotuck",
#   'twitter_handle': '9to5mac',
#   'urls': ['https://9to5mac.com/2021/06/02/apple-confirms-apple-card-outage/'],
#   'username': '9to5mac',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 43.61666666666667,
#   'total': 88,
#   'average_nreactions': 107.5,
#   'cut_off': 86.0},
#  {'conversation_id': '1400095364871491589',
#   'date': '2021-06-02 15:22:02',
#   'hashtags': [],
#   'id': '1400095364871491589',
#   'language': 'en',
#   'link': 'https://twitter.com/9to5mac/status/1400095364871491589',
#   'name': '9to5Mac.com',
#   'nlikes': 63,
#   'nreplies': 0,
#   'nretweets': 12,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Gallery: Swift Student Challenge winners begin receiving exclusive WWDC21 swag  https://t.co/l7ypg08l4p by @ChanceHMiller',
#   'twitter_handle': '9to5mac',
#   'urls': ['https://9to5mac.com/2021/06/02/wwdc-2021-swag-challenge-winners/'],
#   'username': '9to5mac',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 40.766666666666666,
#   'total': 75,
#   'average_nreactions': 107.5,
#   'cut_off': 86.0},
#  {'conversation_id': '1400095251759517703',
#   'date': '2021-06-02 15:21:35',
#   'hashtags': [],
#   'id': '1400095251759517703',
#   'language': 'en',
#   'link': 'https://twitter.com/globalnews/status/1400095251759517703',
#   'name': 'Globalnews.ca',
#   'nlikes': 18,
#   'nreplies': 2,
#   'nretweets': 1,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': "Wednesday marks the third straight day Ontario's case counts are below a thousand.   https://t.co/b7z5Fv5oOH",
#   'twitter_handle': 'globalnews',
#   'urls': ['https://trib.al/hj7CzMC'],
#   'username': 'globalnews',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 41.21666666666667,
#   'total': 21,
#   'average_nreactions': 68.0,
#   'cut_off': 54.4},
#  {'conversation_id': '1400097129322844171',
#   'date': '2021-06-02 15:29:02',
#   'hashtags': [],
#   'id': '1400097129322844171',
#   'language': 'en',
#   'link': 'https://twitter.com/Gizmodo/status/1400097129322844171',
#   'name': 'Gizmodo',
#   'nlikes': 6,
#   'nreplies': 1,
#   'nretweets': 1,
#   'photos': [],
#   'retweet': False,
#   'source': '',
#   'thumbnail': '',
#   'tweet': 'Please Give All the Awards to This Mind-Melting Game That Uses 2D Instant Camera Photos to Solve 3D Puzzles  https://t.co/E25p1FINI0',
#   'twitter_handle': 'Gizmodo',
#   'urls': ['http://dlvr.it/S0wV1x'],
#   'username': 'Gizmodo',
#   'video': 0,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 33.766666666666666,
#   'total': 8,
#   'average_nreactions': 82.66666666666667,
#   'cut_off': 66.13333333333334},
#  {'conversation_id': '1400094854311337987',
#   'date': '2021-06-02 15:20:00',
#   'hashtags': [],
#   'id': '1400094854311337987',
#   'language': 'en',
#   'link': 'https://twitter.com/PulseGhana/status/1400094854311337987',
#   'name': 'Pulse Ghana',
#   'nlikes': 32,
#   'nreplies': 2,
#   'nretweets': 2,
#   'photos': ['https://pbs.twimg.com/media/E24gtJLXwAIxqQ6.jpg'],
#   'retweet': False,
#   'source': '',
#   'thumbnail': 'https://pbs.twimg.com/media/E24gtJLXwAIxqQ6.jpg',
#   'tweet': 'Man jailed 9 months for beating stranger who spanked his girlfriend’s buttocks  https://t.co/dX8GbN411j  https://t.co/cVpjpCbZxb',
#   'twitter_handle': 'pulseghana',
#   'urls': ['https://bit.ly/34BRLlA'],
#   'username': 'PulseGhana',
#   'video': 1,
#   'run_time': '2021-06-02 16:02:48',
#   'time_since_tweet': 42.8,
#   'total': 36,
#   'average_nreactions': 109.53846153846152,
#   'cut_off': 87.63076923076922}]

# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb://ukeme:master09Master@cluster0-shard-00-00.ez7zo.mongodb.net:27017,cluster0-shard-00-01.ez7zo.mongodb.net:27017,cluster0-shard-00-02.ez7zo.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
db = client.twiitter

# %%
def save_to_unfiltered_collection(df):
    unfiltered_collection = db.unfiltered_collection
    cur = unfiltered_collection.count_documents({})
    print('We had %s  entries at the start' % cur)
    
    
    id_list=list(unfiltered_collection.find({}, {"_id": 0, "id": 1}))
    id_list=list((val for dic in id_list for val in dic.values()))
    
    for dfs in df.to_dict('records'):
        if dfs['id'] not in id_list:
            unfiltered_collection.insert_one(dfs)

save_to_unfiltered_collection(new_df_1)

def save_to_filtered_collection(df):
    filtered_collection = db.filtered_collection
    cur = filtered_collection.count_documents({})
    print('We had %s  entries at the start' % cur)
    
    
    id_list=list(filtered_collection.find({}, {"_id": 0, "id": 1}))
    id_list=list((val for dic in id_list for val in dic.values()))
    
    for dfs in df.to_dict('records'):
        if dfs['id'] not in id_list:
            filtered_collection.insert_one(dfs)

save_to_filtered_collection(new_filtered)
# Out:
# We had 120  entries at the start

# %%
def save_to_filtered_collection(df):
    filtered_collection = db.filtered_collection
    cur = filtered_collection.count_documents({})
    print('We had %s  entries at the start' % cur)
    
    
    id_list=list(filtered_collection.find({}, {"_id": 0, "id": 1}))
    id_list=list((val for dic in id_list for val in dic.values()))
    
    for dfs in df.to_dict('records'):
        if dfs['id'] not in id_list:
            filtered_collection.insert_one(dfs)

save_to_filtered_collection(new_filtered)
# Out:
# We had 0  entries at the start
